# %%
from IPython.display import clear_output 
# !git clone https://github.com/sangyun884/HR-VITON.git
# %cd ./HR-VITON/
# Out:
# Cloning into 'HR-VITON'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 123 (delta 29), reused 18 (delta 12), pack-reused 74
# Receiving objects: 100% (123/123), 16.05 MiB | 47.24 MiB/s, done.
# Resolving deltas: 100% (63/63), done.
# /content/HR-VITON

# %% [markdown]
# Rename folder dataset -> data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Create a new folder name checkpoint

# %%
# !mkdir checkpoint

# %%
# !cp -av '/content/drive/MyDrive/data_499/hrvitonckpt/mtviton.pth' '/content/HR-VITON/checkpoint/'
# Out:
# '/content/drive/MyDrive/data_499/hrvitonckpt/mtviton.pth' -> '/content/HR-VITON/checkpoint/mtviton.pth'

# %%
# !cp -av '/content/drive/MyDrive/data_499/hrvitonckpt/discriminator_mtviton.pth' '/content/HR-VITON/checkpoint/'
# Out:
# '/content/drive/MyDrive/data_499/hrvitonckpt/discriminator_mtviton.pth' -> '/content/HR-VITON/checkpoint/discriminator_mtviton.pth'

# %%
# !cp -av '/content/drive/MyDrive/data_499/hrvitonckpt/gen.pth' '/content/HR-VITON/checkpoint/'
# Out:
# '/content/drive/MyDrive/data_499/hrvitonckpt/gen.pth' -> '/content/HR-VITON/checkpoint/gen.pth'

# %% [markdown]
# Last checkpoint into -> ./eval_models/weights/v0.1

# %%
# !mkdir /content/HR-VITON/eval_models/weights

# %%
# !mkdir /content/HR-VITON/eval_models/weights/v0.1

# %%
# !cp -av '/content/drive/MyDrive/data_499/hrvitonckpt/alex.pth' '/content/HR-VITON/eval_models/weights/v0.1/'
# Out:
# '/content/drive/MyDrive/data_499/hrvitonckpt/alex.pth' -> '/content/HR-VITON/eval_models/weights/v0.1/alex.pth'

# %%
# !cp -av '/content/drive/MyDrive/data_499/paired_data' '/content/HR-VITON/'
clear_output()

# %%
# !mv /content/HR-VITON/paired_data /content/HR-VITON/data/

# %% [markdown]
# Dropbox Link: https://www.dropbox.com/s/10bfat0kg4si1bu/zalando-hd-resized.zip?dl=0
#
# !wget https://www.dropbox.com/s/10bfat0kg4si1bu/zalando-hd-resized.zip?dl=0

# %% [markdown]
# # Train

# %%
# !pip install tensorboardX
# !pip install torchgeometry
# !pip install Pillow
# !pip install scikit-image 
# !pip install scipy
clear_output()

# %%
# !nvidia-smi
# Out:
# Sun Oct 30 19:50:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   26C    P0    42W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Train Try -on Condition Generator

# %% [markdown]
# ### Install apex NVIDIA , dependecies for Try on Generator

# %%
# !git clone https://github.com/NVIDIA/apex
# %cd /content/HR-VITON/apex
# !pip install -v --disable-pip-version-check --no-cache-dir ./
clear_output()

# %% [markdown]
# ## Train Try -on Image Generator

# %% [markdown]
# ## FOR DEMO

# %%
# %cd /content/HR-VITON/
# !python train_condition.py --cuda True --name condition_gen --workers 4 --batch-size 8 --display_count 9 --save_count 9 --keep_step 99 --gpu_ids 0 --test_datasetting paired --Ddownx2 --Ddropout --lasttvonly --interflowloss --occlusion
# Out:
# /content/HR-VITON
# Namespace(CElamda=10, D_lr=0.0002, Ddownx2=True, Ddropout=True, GANlambda=1, G_D_seperate=False, G_lr=0.0002, add_lasttv=False, batch_size=8, checkpoint_dir='checkpoints', clothmask_composition='warp_grad', cuda='True', data_list='train_pairs.txt', datamode='train', dataroot='./data/', display_count=9, edgeawaretv='no_edge', fine_height=256, fine_width=192, fp16=False, gpu_ids='0', interflowloss=True, keep_step=99, lasttvonly=True, load_step=0, name='condition_gen', no_GAN_loss=False, no_test_visualize=False, num_D=2, num_test_visualize=3, occlusion=True, out_layer='relu', output_nc=13, save_count=9, semantic_nc=13, shuffle=False, spectral=False, tensorboard_count=100, tensorboard_dir='tensorboard', test_data_list='test_pairs.txt', test_dataroot='./data/', test_datasetting='paired', tocg_checkpoint='', tvlambda=2, upsample='bilinear', val_count=1000, warp_feature='T1', workers=4)
# Start to train condition_gen!
# ...

# %% [markdown]
# ### Install apex NVIDIA , dependecies for Try on Generator

# %%
# !git clone https://github.com/NVIDIA/apex
# %cd /content/HR-VITON/apex
# !pip install -v --disable-pip-version-check --no-cache-dir ./
clear_output()

# %% [markdown]
# ## Train Try -on Image Generator

# %%
# %cd /content/HR-VITON
# !python train_generator.py --name ramisa_train_gen -b 4 -j 4 --gpu_ids 0 --cuda True --fp16 --tocg_checkpoint '/content/HR-VITON/checkpoints/condition_gen/tocg_final.pth' --display_count 99 --save_count 99 --keep_step 900 --decay_step 99 --occlusion
# Out:
# /content/HR-VITON
# ...

# %%
# !cp -av "/content/HR-VITON" "/content/drive/MyDrive"

# %%
# !cp -av /content/HR-VITON/tensorboard /content/drive/MyDrive/data_499/paired_tensorboard/
clear_output()

# %%
# !cp -av /content/HR-VITON/checkpoints /content/drive/MyDrive/data_499/paired_checkpoints/
clear_output()

# %%
# !rm -rf /content/HR-VITON/checkpoints/ramisa_train_gen
# !rm -rf /content/HR-VITON/tensorboard/ramisa_train_gen

# %%
cvat pass: MAdrVv39m7XBqUp

# %% [markdown]
# # For without pretrained model load Paired Data

# %%
# %cd /content/HR-VITON/
# !python train_condition.py --name condition_gen --workers 2 --batch-size 4 --display_count 9 --save_count 99 --keep_step 99 --gpu_ids 0 --test_datasetting paired --Ddownx2 --Ddropout --lasttvonly --interflowloss --occlusion
# Out:
# /content/HR-VITON
# Namespace(CElamda=10, D_lr=0.0002, Ddownx2=True, Ddropout=True, GANlambda=1, G_D_seperate=False, G_lr=0.0002, add_lasttv=False, batch_size=4, checkpoint_dir='checkpoints', clothmask_composition='warp_grad', data_list='train_pairs.txt', datamode='train', dataroot='./data/', display_count=9, edgeawaretv='no_edge', fine_height=256, fine_width=192, fp16=False, gpu_ids='0', interflowloss=True, keep_step=99, lasttvonly=True, load_step=0, name='condition_gen', no_GAN_loss=False, no_test_visualize=False, num_D=2, num_test_visualize=3, occlusion=True, out_layer='relu', output_nc=13, save_count=99, semantic_nc=13, shuffle=False, spectral=False, tensorboard_count=100, tensorboard_dir='tensorboard', test_data_list='test_pairs.txt', test_dataroot='./data/', test_datasetting='paired', tocg_checkpoint='', tvlambda=2, upsample='bilinear', val_count=1000, warp_feature='T1', workers=2)
# Start to train condition_gen!
# ...

# %%
# !git clone https://github.com/NVIDIA/apex
# %cd /content/HR-VITON/apex
# !pip install -v --disable-pip-version-check --no-cache-dir ./
clear_output()

# %%
# %cd /content/HR-VITON
# !python train_generator.py --name ramisa_train_gen -b 4 -j 4 --gpu_ids 0 --fp16 --tocg_checkpoint '/content/HR-VITON/checkpoints/condition_gen/tocg_final.pth' --display_count 99 --save_count 999 --keep_step 900 --decay_step 99 --occlusion
# Out:
# /content/HR-VITON
# ...

# %%
# !cp -av /content/HR-VITON/checkpoints /content/drive/MyDrive/data_499/paired_checkpoints_without_pretrained/
clear_output()
